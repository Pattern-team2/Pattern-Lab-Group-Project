# %%
x = open(r'C:\Users\Riyasaat Ahmed Rahul\Desktop\pattern papers\Data\A.thaliana1000indep_neg.fasta', 'r')

a = x.read()

x.close()

# %%
a = a.replace(">-sample\n", "555")
a = a.replace("\n", "")
sequence = list(a.split("555")) 
sequence.pop(0)

main_data = ''
for i in range(1000):
    main_data += '>'+str(i)+'|1|training\n'
    main_data += sequence[i]+'\n'
      
print(main_data)
# Out:
# >0|1|training
# CCUGAGGGUAACAAGAGUAUCAGUAAGAUGAUCCAACUGUA
# >1|1|training
# ACAUUUUACCCAGUAAUGUGCGUCGGAAGAAUCAACCUCUU
# >2|1|training
# CCGGAUCAAAACGAAGAUGGCUCGGUGAUUCUCGCGACGUG
# >3|1|training
# GUCCGAUGCUCCGUCGUCUUCCCCGGAUGCCACGGCGUCGC
# >4|1|training
# GAUGAGUCAAAGGAGGAGAACCUUAGAGCUCACAGCGAAAA
# >5|1|training
# UGGAGAAUUUGUUGAUUGUUCCAUUCCUCAUACUCCUAAAU
# >6|1|training
# ACAUCCUUGCGUCUCAAAGGCACAACAUUACUCGGCGGUAG
# >7|1|training
# UGAAGCUGCGGAAUUGGAAACAUCUUCAUUGCAAGAGAUAU
# >8|1|training
# GGUUGAGUGGGCAGAAGGUGCAUUUGUUGCACAGAAGCAAC
# >9|1|training
# GGAGCAUGUCCUGAUCAUGGCGCUCUAGUGUAUGAGUACAU
# >10|1|training
# ACCAUUUCAACUGACUAUGACUUGAAGGGUGAUGAGAAAAC
# >11|1|training
# UACCUGUAAUUAUGGUGAAUCAUUUAUAUCUUCCAUAAGAA
# >12|1|training
# UCCAAAUGGUAAGAACGUGGCUGUGAAAAGAUUAGUGUUUA
# >13|1|training
# UGAGAAGGAGAAUUGGAAGUCUGUAGACACCAGUCUGCUGG
# >14|1|training
# CAGAUGGAACGGUUAUGAUACUUCAACCUACCGUCAUGUGG
# >15|1|training
# CCGGCACAAGGCUCUACAAGCUACCGUAUAACGCCACUGUU
# >16|1|training
# ...

# %%
f = open(r'C:\Users\Riyasaat Ahmed Rahul\Desktop\pattern papers\Data\1.txt', 'a')
f.write(main_data)
f.close()
